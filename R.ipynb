# %% [markdown]
# # Warm-Up Exercise

# %%
# install.packages('ggplot2', repos='http://cran.us.r-project.org')

# %%
# install.packages('GetoptLong', repos='http://cran.us.r-project.org')

# %%
library(ggplot2)
library(repr)
library(GetoptLong)

options(repr.plot.width=16, repr.plot.height=8)

# %%
df <- read.csv('https://sds-platform-private.s3-us-east-2.amazonaws.com/uploads/P2-Mispriced-Diamonds.csv')
head(df)
# Out:
#   carat clarity price
# 1 0.23  SI2     326
# 2 0.21  SI1     326
# 3 0.23  VS1     327
# 4 0.29  VS2     334
# 5 0.31  SI2     335
# 6 0.24  VVS2    336

# %%
ggplot(data=df[df$carat<2.5, ], aes(x=carat, y=price, colour=clarity)) + 
geom_point(alpha=0.1) + 
geom_smooth()
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# # Variables and Types

# %% [markdown]
# ## Types

# %%
x <- 2L
typeof(x)
# Out:
# [1] "integer"

# %%
y <- 2.5
typeof(y)
# Out:
# [1] "double"

# %%
x <- 2
typeof(x)
# Out:
# [1] "double"

# %%
z <- 3 + 2i
typeof(z)
# Out:
# [1] "complex"

# %%
a <- "h"
typeof(a)
# Out:
# [1] "character"

# %%
a <- 'h'
typeof(a)
# Out:
# [1] "character"

# %%
q1 <- T
typeof(q1)
# Out:
# [1] "logical"

# %%
q2 <- FALSE
typeof(q2)
# Out:
# [1] "logical"

# %% [markdown]
# ## Using Variables

# %%
A <- 10
B <- 5

# %%
C <- A + B
C
# Out:
# [1] 15

# %%
var1 <- 2.5
var2 <- 4

# %%
result <- var1 / var2
result
# Out:
# [1] 0.625

# %%
answer <- sqrt(var2)
answer
# Out:
# [1] 2

# %%
greeting <- 'Hello'
name <- 'Bob'
message <- paste(greeting, name)
message
# Out:
# [1] "Hello Bob"

# %%
qq('@{greeting} @{name}')
# Out:
# [1] "Hello Bob"

# %%
paste('A', 'B', 'C')
# Out:
# [1] "A B C"
